# %% [markdown]
# ## introduce the data
#
# 1 My subject is going to analysis about economy and growth in GDP.
#
# 2 I choose this project is due to my second major in UBC which is Economy.
#   I have been learned lots of lectures about economy,
#   and I want to combine my mathematics and economy knowledage together in my project2.
#   Therefore, I choose economy dataset and use the math210 method to analysis it.
#
# 3 I find this dataset as following website
# http://data.worldbank.org/data-catalog/GDP-ranking-table
#
# 4 the reader can find all the information about GDP ranking in this website. Just open the web, and download all the documents they need.

# %% [markdown]
# ## Ask qustions
#
# In this project, I have 4 quesions that I wold like to explore
# 1 what are the top3 GDP countries in this world, and is it same as last year?
# 2 what can we see from the GDP financial amout about this dataset?
# 3 Is GDP ranking  related to location?
# 4 Is GDP ranking  related to health as well?
#
# Firstly, I need to introduce the definition of GDP
#
# *"Gross domestic product (GDP)*:
#
# **the monetary value of all the finished goods and services produced within a country's borders in a specific time period. Though GDP is usually calculated on an annual basis, it can be calculated on a quarterly basis as well. GDP includes all private and public consumption, government outlays, investments and exports minus imports that occur within a defined territory. Put simply, GDP is a broad measurement of a nation’s overall economic activity."**
#
# Gross domestic product can be calculated using the following formula:
#
# GDP = C + G + I + NX
#
# where
#
# C is equal to all private consumption, or consumer spending, in a nation's economy, G is the sum of government spending, I is the sum of all the country's investment, including businesses capital expenditures and NX is the nation's total net exports, calculated as total exports minus total imports (NX = Exports - Imports).
#
# resource from online, the website is
# http://www.investopedia.com/terms/g/gdp.asp
#
# Then, I am starting to analysis the dataset I get from
# *World Bank http://data.worldbank.org*
#
# ## quick summary from datasat
#
# 1 From 2015-2016, I can see that top3 countries for GDP are: USA, China, and Japan
#   From 2014-2015. I try to find the dataset from world bank website, but I faided. I just find the GDP ranking about 2010.
#   and it is the same ranking as 2015-2016.
#
# 2 What can we see from GDP? This is a more economy question I thought.
#   In the economy world, there are two parts
#
#   *The pitfalls of GDP*
#
#   *Revisions*
#
#   In another words, it means health and wealth somehow. why does it happen?
#
#   Usually, when we don not have much information about GDP, we choose to test a country health and wealth to account in instead of GDP
#
#  ** this part is more economy , if you are interested in, you can reader a quick summary online by following link:
#  http://www.telegraph.co.uk/finance/economics/11159277/What-does-GDP-really-tell-us-about-economic-growth.html
#
#  3 Basicly, I thought it is kind of regionalism.
#    From top 10 we can see ,
#    3 Asian countries : China & Japan & India, and the ranking is 2 &3 & 9
#    1 North America country: USA, and the ranking is 1
#    rest counties are located in Europe.
#
#   As a result, 60% high GDP countries are from Europe
#
#   (By the way , Canada is ranked by 11)
#
# 4 I checked some notes from google and baidu. I don not think that GDP means everything about good quality of life.
#   For example, GDP ranking of China is higher than Canada. However, canadian medical treatment cause is much better than China even most of     Aisn countis such as India

# %% [markdown]
# ## explore the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
GDP = pd.read_csv('gdp.csv',encoding='latin')

# %%
GDP.head(15)
# Out:
#    Unnamed: 0 Gross domestic product 2014  Unnamed: 2          Unnamed: 3  \
# 0         NaN                         NaN         NaN                 NaN
# 1         NaN                         NaN         NaN                 NaN
# 2         NaN                     Ranking         NaN             Economy
# 3         NaN                         NaN         NaN                 NaN
# 4         USA                           1         NaN       United States
# 5         CHN                           2         NaN               China
# 6         JPN                           3         NaN               Japan
# 7         DEU                           4         NaN             Germany
# 8         GBR                           5         NaN      United Kingdom
# 9         FRA                           6         NaN              France
# 10        BRA                           7         NaN              Brazil
# 11        ITA                           8         NaN               Italy
# 12        IND                           9         NaN               India
# 13        RUS                          10         NaN  Russian Federation
# 14        CAN                          11         NaN              Canada
#
#       Unnamed: 4 Unnamed: 5
# 0            NaN        NaN
# 1   (millions of        NaN
# 2    US dollars)        NaN
# 3            NaN        NaN
# 4     17,419,000        NaN
# 5     10,354,832        NaN
# 6      4,601,461        NaN
# 7      3,868,291        NaN
# 8      2,988,893        NaN
# 9      2,829,192        NaN
# 10     2,416,636        NaN
# 11     2,141,161        NaN
# 12     2,048,517        NaN
# 13     1,860,598          a
# 14     1,785,387        NaN

# %% [markdown]
# we just analysis top10 datasat about GDP ranking, and there is the data that we can check

# %%
GDP.head(169)
# Out:
#     Unnamed: 0 Gross domestic product 2014  Unnamed: 2          Unnamed: 3  \
# 0          NaN                         NaN         NaN                 NaN
# 1          NaN                         NaN         NaN                 NaN
# 2          NaN                     Ranking         NaN             Economy
# 3          NaN                         NaN         NaN                 NaN
# 4          USA                           1         NaN       United States
# 5          CHN                           2         NaN               China
# 6          JPN                           3         NaN               Japan
# 7          DEU                           4         NaN             Germany
# 8          GBR                           5         NaN      United Kingdom
# 9          FRA                           6         NaN              France
# 10         BRA                           7         NaN              Brazil
# 11         ITA                           8         NaN               Italy
# 12         IND                           9         NaN               India
# 13         RUS                          10         NaN  Russian Federation
# 14         CAN                          11         NaN              Canada
# 15         AUS                          12         NaN           Australia
# 16         KOR                          13         NaN         Korea, Rep.
# 17         ESP                          14         NaN               Spain
# 18         MEX                          15         NaN              Mexico
# 19         IDN                          16         NaN           Indonesia
# 20         NLD                          17         NaN         Netherlands
# 21         TUR                          18         NaN              Turkey
# 22         SAU                          19         NaN        Saudi Arabia
# 23         CHE                          20         NaN         Switzerland
# 24         SWE                          21         NaN              Sweden
# 25         NGA                          22         NaN             Nigeria
# 26         POL                          23         NaN              Poland
# 27         ARG                          24         NaN           Argentina
# 28         BEL                          25         NaN             Belgium
# 29         NOR                          26         NaN              Norway
# ..         ...                         ...         ...                 ...
# 139        ARM                         136         NaN             Armenia
# 140        MKD                         137         NaN      Macedonia, FYR
# 141        MDG                         138         NaN          Madagascar
# 142        MLT                         139         NaN               Malta
# 143        BEN                         140         NaN               Benin
# 144        TJK                         141         NaN          Tajikistan
# 145        HTI                         142         NaN               Haiti
# 146        BHS                         143         NaN        Bahamas, The
# 147        NER                         144         NaN               Niger
# 148        MDA                         145         NaN             Moldova
# 149        RWA                         146         NaN              Rwanda
# 150        KGZ                         147         NaN     Kyrgyz Republic
# 151        KSV                         148         NaN              Kosovo
# 152        GIN                         149         NaN              Guinea
# 153        SOM                         150         NaN             Somalia
# 154        BMU                         151         NaN             Bermuda
# 155        LIE                         152         NaN       Liechtenstein
# 156        SUR                         153         NaN            Suriname
# 157        MRT                         154         NaN          Mauritania
# 158        SLE                         155         NaN        Sierra Leone
# 159        MNE                         156         NaN          Montenegro
# 160        FJI                         157         NaN                Fiji
# 161        TGO                         158         NaN                Togo
# 162        SWZ                         159         NaN           Swaziland
# 163        BRB                         160         NaN            Barbados
# 164        MWI                         161         NaN              Malawi
# 165        ADO                         162         NaN             Andorra
# 166        GUY                         163         NaN              Guyana
# 167        BDI                         164         NaN             Burundi
# 168        MDV                         165         NaN            Maldives
#
#        Unnamed: 4 Unnamed: 5
# 0             NaN        NaN
# 1    (millions of        NaN
# 2     US dollars)        NaN
# 3             NaN        NaN
# 4      17,419,000        NaN
# 5      10,354,832        NaN
# 6       4,601,461        NaN
# 7       3,868,291        NaN
# 8       2,988,893        NaN
# 9       2,829,192        NaN
# 10      2,416,636        NaN
# 11      2,141,161        NaN
# 12      2,048,517        NaN
# 13      1,860,598          a
# 14      1,785,387        NaN
# 15      1,454,675        NaN
# 16      1,410,383        NaN
# 17      1,381,342        NaN
# 18      1,294,690        NaN
# 19        888,538        NaN
# 20        879,319        NaN
# 21        798,429        NaN
# 22        753,832        NaN
# 23        701,037        NaN
# 24        571,090        NaN
# 25        568,508        NaN
# 26        544,967        NaN
# 27        537,660        NaN
# 28        531,547        NaN
# 29        499,817        NaN
# ..            ...        ...
# 139        11,644        NaN
# 140        11,324        NaN
# 141        10,593        NaN
# 142         9,643        NaN
# 143         9,575        NaN
# 144         9,242        NaN
# 145         8,713        NaN
# 146         8,511        NaN
# 147         8,169        NaN
# 148         7,962          f
# 149         7,890        NaN
# 150         7,404        NaN
# 151         7,387        NaN
# 152         6,624        NaN
# 153         5,707        NaN
# 154         5,574        NaN
# 155         5,488        NaN
# 156         5,210        NaN
# 157         5,061        NaN
# 158         4,838        NaN
# 159         4,588        NaN
# 160         4,532        NaN
# 161         4,518        NaN
# 162         4,413        NaN
# 163         4,355        NaN
# 164         4,258        NaN
# 165         3,249        NaN
# 166         3,097        NaN
# 167         3,094        NaN
# 168         3,062        NaN
#
# [169 rows x 6 columns]

# %%
GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 0 to 241
# Data columns (total 6 columns):
# Unnamed: 0                     228 non-null object
# Gross domestic product 2014    202 non-null object
# Unnamed: 2                     0 non-null float64
# Unnamed: 3                     229 non-null object
# Unnamed: 4                     230 non-null object
# Unnamed: 5                     7 non-null object
# dtypes: float64(1), object(5)
# memory usage: 13.2+ KB

# %%
GDP.tail(20)
# Out:
#     Unnamed: 0                        Gross domestic product 2014  Unnamed: 2  \
# 222        LIC                                                NaN         NaN
# 223        MIC                                                NaN         NaN
# 224        LMC                                                NaN         NaN
# 225        UMC                                                NaN         NaN
# 226        LMY                                                NaN         NaN
# 227        EAP                                                NaN         NaN
# 228        ECA                                                NaN         NaN
# 229        LAC                                                NaN         NaN
# 230        MNA                                                NaN         NaN
# 231        SAS                                                NaN         NaN
# 232        SSA                                                NaN         NaN
# 233        HIC                                                NaN         NaN
# 234        EMU                                                NaN         NaN
# 235        NaN                                                NaN         NaN
# 236        NaN                                .. Not available.           NaN
# 237        NaN  Note: Rankings include only those economies wi...         NaN
# 238        NaN  a. Based on data from official statistics of U...         NaN
# 239        NaN  make any judgment on the legal or other status...         NaN
# 240        NaN  b. Includes Former Spanish Sahara.  c. Covers ...         NaN
# 241        NaN  e. Excludes Abkhazia and South Ossetia.  f. Ex...         NaN
#
#                        Unnamed: 3  Unnamed: 4 Unnamed: 5
# 222                    Low income     397,849        NaN
# 223                 Middle income  24,748,448        NaN
# 224           Lower middle income   5,781,069        NaN
# 225           Upper middle income  18,958,149        NaN
# 226           Low & middle income  25,148,400        NaN
# 227           East Asia & Pacific  12,609,716        NaN
# 228         Europe & Central Asia   1,817,461        NaN
# 229     Latin America & Caribbean   4,845,035        NaN
# 230    Middle East & North Africa   1,556,768        NaN
# 231                    South Asia   2,588,688        NaN
# 232            Sub-Saharan Africa   1,728,322        NaN
# 233                   High income  52,850,488        NaN
# 234                     Euro area  13,410,232        NaN
# 235                           NaN         NaN        NaN
# 236                           NaN         NaN        NaN
# 237                           NaN         NaN        NaN
# 238                           NaN         NaN        NaN
# 239                           NaN         NaN        NaN
# 240                           NaN         NaN        NaN
# 241                           NaN         NaN        NaN

# %% [markdown]
# we can see that the lower income does effect the GDP form above data

# %% [markdown]
# ## all the finding
# firstly, I need to provide all the resource that I get from online as following :
#
# I find this dataset as following website http://data.worldbank.org/data-catalog/GDP-ranking-table
#  dataset I get from World Bank http://data.worldbank.org
#  GDP resource from online, the website is http://www.investopedia.com/terms/g/gdp.asp
#  this part is more economy , if you are interested in, you can reader a quick summary online by following link: http://www.telegraph.co.uk/finance/economics/11159277/What-does-GDP-really-tell-us-about-economic-growth.html
#
# seconedly, I would like to summary this project
#
# From economy part, we can see that GDP effects lots of aspects such as health, wealth ,and income
# From datasat we analysis, we can see it is kind of regionalism as we list above
